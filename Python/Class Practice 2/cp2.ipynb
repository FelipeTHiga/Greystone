# %%
#pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("../Python-DataFiles/Lesson 2/hotel_bookings.csv",
                  skiprows = 3, 
                  skipfooter = 1, 
                  engine="python",
                  parse_dates=["reservation_status_date"],
                  dayfirst=True)

# %% [markdown]
# ### Viewing and Inspecting data

# %%
df.head()
# Out:
#    reservation_no         hotel  is_canceled  lead_time  arrival_date_year  \
# 0           12603  Resort Hotel            0        342               2015
# 1           12604  Resort Hotel            0        737               2015
# 2           12605  Resort Hotel            0          7               2015
# 3           12606  Resort Hotel            0         13               2015
# 4           12607  Resort Hotel            0         14               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
df.tail()
# Out:
#         reservation_no       hotel  is_canceled  lead_time  arrival_date_year  \
# 119385          131988  City Hotel            0         23               2017
# 119386          131989  City Hotel            0        102               2017
# 119387          131990  City Hotel            0         34               2017
# 119388          131991  City Hotel            0        109               2017
# 119389          131992  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   reservation_no                  119390 non-null  int64
#  1   hotel                           119390 non-null  object
#  2   is_canceled                     119390 non-null  int64
#  3   lead_time                       119390 non-null  int64
#  4   arrival_date_year               119390 non-null  int64
#  5   arrival_date_month              119390 non-null  object
#  6   arrival_date_week_number        119390 non-null  int64
#  7   arrival_date_day_of_month       119390 non-null  int64
#  8   stays_in_weekend_nights         119390 non-null  int64
#  9   stays_in_week_nights            119390 non-null  int64
#  10  adults                          119390 non-null  int64
#  11  children                        119386 non-null  float64
# ...

# %%
df.size
# Out:
# 3939870

# %%
df.shape
# Out:
# (119390, 33)

# %%
df.describe()
# Out:
#        reservation_no    is_canceled      lead_time  arrival_date_year  \
# count   119390.000000  119390.000000  119390.000000      119390.000000
# mean     72297.500000       0.370416     104.011416        2016.156554
# min      12603.000000       0.000000       0.000000        2015.000000
# 25%      42450.250000       0.000000      18.000000        2016.000000
# 50%      72297.500000       0.000000      69.000000        2016.000000
# 75%     102144.750000       1.000000     160.000000        2017.000000
# max     131992.000000       1.000000     737.000000        2017.000000
# std      34465.068657       0.482918     106.863097           0.707476
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# ...

# %%
df["reservation_no"].describe()
# Out:
# count    119390.000000
# mean      72297.500000
# std       34465.068657
# min       12603.000000
# 25%       42450.250000
# 50%       72297.500000
# 75%      102144.750000
# max      131992.000000
# Name: reservation_no, dtype: float64

# %% [markdown]
# ### Selecting and sorting data

# %%
arrival_month = df["arrival_date_month"]

arrival_month.describe()
# Out:
# count     119390
# unique        12
# top       August
# freq       13877
# Name: arrival_date_month, dtype: object

# %%
df[["hotel", "arrival_date_month", "stays_in_weekend_nights", "stays_in_week_nights",
"reservation_status"]]
# Out:
#                hotel arrival_date_month  stays_in_weekend_nights  \
# 0       Resort Hotel               July                        0
# 1       Resort Hotel               July                        0
# 2       Resort Hotel               July                        0
# 3       Resort Hotel               July                        0
# 4       Resort Hotel               July                        0
# ...              ...                ...                      ...
# 119385    City Hotel             August                        2
# 119386    City Hotel             August                        2
# 119387    City Hotel             August                        2
# 119388    City Hotel             August                        2
# 119389    City Hotel             August                        2
#
#         stays_in_week_nights reservation_status
# 0                          0          Check-Out
# 1                          0          Check-Out
# ...

# %%
sdf = df[["hotel", "arrival_date_month", "stays_in_weekend_nights", "stays_in_week_nights",
"reservation_status"]]

sdf
# Out:
#                hotel arrival_date_month  stays_in_weekend_nights  \
# 0       Resort Hotel               July                        0
# 1       Resort Hotel               July                        0
# 2       Resort Hotel               July                        0
# 3       Resort Hotel               July                        0
# 4       Resort Hotel               July                        0
# ...              ...                ...                      ...
# 119385    City Hotel             August                        2
# 119386    City Hotel             August                        2
# 119387    City Hotel             August                        2
# 119388    City Hotel             August                        2
# 119389    City Hotel             August                        2
#
#         stays_in_week_nights reservation_status
# 0                          0          Check-Out
# 1                          0          Check-Out
# ...

# %%
sdf.shape
# Out:
# (119390, 5)

# %%
sdf.describe()
# Out:
#        stays_in_weekend_nights  stays_in_week_nights
# count            119390.000000         119390.000000
# mean                  0.927599              2.500302
# std                   0.998613              1.908286
# min                   0.000000              0.000000
# 25%                   0.000000              1.000000
# 50%                   1.000000              2.000000
# 75%                   2.000000              3.000000
# max                  19.000000             50.000000

# %%
sdf["stays_in_week_nights"].max()
# Out:
# 50

# %%
sdf["stays_in_week_nights"].min()
# Out:
# 0

# %%
sdf["stays_in_weekend_nights"].max()
# Out:
# 19

# %%
sdf["stays_in_weekend_nights"].min()
# Out:
# 0

# %%
sdf[sdf["stays_in_week_nights"] == 50]
# Out:
#               hotel arrival_date_month  stays_in_weekend_nights  \
# 14038  Resort Hotel               July                       19
#
#        stays_in_week_nights reservation_status
# 14038                    50          Check-Out

# %%
sdf[sdf["reservation_status"] == "Check-Out"]
# Out:
#                hotel arrival_date_month  stays_in_weekend_nights  \
# 0       Resort Hotel               July                        0
# 1       Resort Hotel               July                        0
# 2       Resort Hotel               July                        0
# 3       Resort Hotel               July                        0
# 4       Resort Hotel               July                        0
# ...              ...                ...                      ...
# 119385    City Hotel             August                        2
# 119386    City Hotel             August                        2
# 119387    City Hotel             August                        2
# 119388    City Hotel             August                        2
# 119389    City Hotel             August                        2
#
#         stays_in_week_nights reservation_status
# 0                          0          Check-Out
# 1                          0          Check-Out
# ...

# %%
sdf[sdf["reservation_status"] == "Check-Out"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75166 entries, 0 to 119389
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   hotel                    75166 non-null  object
#  1   arrival_date_month       75166 non-null  object
#  2   stays_in_weekend_nights  75166 non-null  int64
#  3   stays_in_week_nights     75166 non-null  int64
#  4   reservation_status       75166 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 3.4+ MB
