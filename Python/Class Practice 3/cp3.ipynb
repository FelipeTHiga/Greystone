# %%
import pandas as pd

# %%
df = pd.read_csv("../Python-DataFiles/Lesson 3/hotel_bookings.csv",
                  skiprows = 3, 
                  skipfooter = 1, 
                  engine="python",
                  parse_dates=["reservation_status_date"],
                  dayfirst=True,
                  index_col="reservation_no")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119390 entries, 12603 to 131992
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.head()
# Out:
#                        hotel  is_canceled  lead_time  arrival_date_year  \
# reservation_no
# 12603           Resort Hotel            0        342               2015
# 12604           Resort Hotel            0        737               2015
# 12605           Resort Hotel            0          7               2015
# 12606           Resort Hotel            0         13               2015
# 12607           Resort Hotel            0         14               2015
#
#                arrival_date_month  arrival_date_week_number  \
# reservation_no
# 12603                        July                        27
# 12604                        July                        27
# 12605                        July                        27
# 12606                        July                        27
# 12607                        July                        27
#
#                 arrival_date_day_of_month  stays_in_weekend_nights  \
# reservation_no
# ...

# %%
df.tail(3)
# Out:
#                      hotel  is_canceled  lead_time  arrival_date_year  \
# reservation_no
# 131990          City Hotel            0         34               2017
# 131991          City Hotel            0        109               2017
# 131992          City Hotel            0        205               2017
#
#                arrival_date_month  arrival_date_week_number  \
# reservation_no
# 131990                     August                        35
# 131991                     August                        35
# 131992                     August                        35
#
#                 arrival_date_day_of_month  stays_in_weekend_nights  \
# reservation_no
# 131990                                 31                        2
# 131991                                 31                        2
# 131992                                 29                        2
#
#                 stays_in_week_nights  adults  ...  deposit_type  agent  \
# ...

# %%
df.loc[df["stays_in_week_nights"].idxmax()]
# Out:
# hotel                                    Resort Hotel
# is_canceled                                         0
# lead_time                                         126
# arrival_date_year                                2016
# arrival_date_month                               July
# arrival_date_week_number                           28
# arrival_date_day_of_month                           5
# stays_in_weekend_nights                            19
# stays_in_week_nights                               50
# adults                                              1
# children                                          0.0
# babies                                              0
# meal                                               HB
# country                                           NaN
# market_segment                                 Direct
# distribution_channel                           Direct
# is_repeated_guest                                   0
# ...

# %%
df.loc[df["stays_in_week_nights"].idxmin(),"hotel"]
# Out:
# 'Resort Hotel'

# %%
# Show the hotel name, arrival month, number of adults, and number of nights in
# the middle of the week but only for guests who arrived for a number of days
# above the middle of the week average.

where = df["stays_in_week_nights"] > df["stays_in_week_nights"].mean()

df.loc[where, ["hotel",
               "arrival_date_month",
               "adults",
               "stays_in_week_nights"]]
# Out:
#                        hotel arrival_date_month  adults  stays_in_week_nights
# reservation_no
# 12611           Resort Hotel               July       2                     3
# 12612           Resort Hotel               July       2                     3
# 12613           Resort Hotel               July       2                     4
# 12614           Resort Hotel               July       2                     4
# 12615           Resort Hotel               July       2                     4
# ...                      ...                ...     ...                   ...
# 131988            City Hotel             August       2                     5
# 131989            City Hotel             August       3                     5
# 131990            City Hotel             August       2                     5
# 131991            City Hotel             August       2                     5
# 131992            City Hotel             August       2                     7
#
# ...

# %%
# Look at the reservation_status column, how many unique values are there in this
# column?

df["reservation_status"].value_counts()

# ans:3 unique values
# Out:
# reservation_status
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: count, dtype: int64

# %%
# Show the value which is repeated the most number of times, and the number of
# times it is repeated

status = df["reservation_status"].value_counts().head(1).index[0]
status
# Out:
# 'Check-Out'

# %%
# Are the values in the Order Number column unique?
df.index.is_unique
# Out:
# True

# %%
where = df["reservation_status"] == status
df.loc[where, "children"].max()
# Out:
# 3.0

# %% [markdown]
# ### Part 2

# %%
dict_for_rename = {"arrival_date_year":"year",
                   "arrival_date_month":"month",
                   "arrival_date_week_number":"week"
                   }
df.rename(columns= dict_for_rename, inplace = True)
df
# Out:
#                        hotel  is_canceled  lead_time  year   month  week  \
# reservation_no
# 12603           Resort Hotel            0        342  2015    July    27
# 12604           Resort Hotel            0        737  2015    July    27
# 12605           Resort Hotel            0          7  2015    July    27
# 12606           Resort Hotel            0         13  2015    July    27
# 12607           Resort Hotel            0         14  2015    July    27
# ...                      ...          ...        ...   ...     ...   ...
# 131988            City Hotel            0         23  2017  August    35
# 131989            City Hotel            0        102  2017  August    35
# 131990            City Hotel            0         34  2017  August    35
# 131991            City Hotel            0        109  2017  August    35
# 131992            City Hotel            0        205  2017  August    35
#
#                 arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
df["stays_in_week_nights"] + df["stays_in_weekend_nights"]
# Out:
# reservation_no
# 12603     0
# 12604     0
# 12605     1
# 12606     1
# 12607     2
#          ..
# 131988    7
# 131989    7
# 131990    7
# 131991    7
# 131992    9
# Length: 119390, dtype: int64

# %%
df["total_nights"] = df["stays_in_week_nights"] + df["stays_in_weekend_nights"]

# %%
df["total_nights"].describe()
# Out:
# count    119390.000000
# mean          3.427900
# std           2.557439
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          69.000000
# Name: total_nights, dtype: float64

# %%
df.sort_values(["hotel","stays_in_weekend_nights"], ascending=False, inplace=True)
df
# Out:
#                        hotel  is_canceled  lead_time  year      month  week  \
# reservation_no
# 26641           Resort Hotel            0        126  2016       July    28
# 26640           Resort Hotel            0        113  2015     August    31
# 22442           Resort Hotel            1        322  2017    January     2
# 46527           Resort Hotel            0         71  2017    January     2
# 14258           Resort Hotel            0         30  2015  September    37
# ...                      ...          ...        ...   ...        ...   ...
# 131953            City Hotel            0        286  2017     August    35
# 131954            City Hotel            0         72  2017     August    35
# 131955            City Hotel            0         63  2017     August    35
# 131956            City Hotel            0         63  2017     August    35
# 131957            City Hotel            0         63  2017     August    35
#
# ...

# %%
df.sort_values("month", inplace=True)

# %%
where = df["reservation_status"] == "No-Show"

df.loc[where,"reservation_status"] = "Canceled"

df["reservation_status"].value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     44224
# Name: count, dtype: int64

# %% [markdown]
# ### Part 3

# %%
df = pd.read_csv("../Python-DataFiles/Lesson 3/police.csv", 
                  engine="python",
                  parse_dates=["stop_date"],
                  dayfirst=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  datetime64[ns]
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  ticket_amount       1082 non-null   float64
#  14  stop_duration       86408 non-null  object
# ...

# %%
df["stop_date"] = pd.to_datetime(df["stop_date"])

# %%
df["stop_year"] = df["stop_date"].dt.year
df["stop_month"] = df["stop_date"].dt.month

df.head()
# Out:
#    stop_date stop_time  county_name driver_gender  driver_age_raw  driver_age  \
# 0 2005-01-02      1:55          NaN             M          1985.0        20.0
# 1 2005-01-18      8:15          NaN             M          1965.0        40.0
# 2 2005-01-23     23:15          NaN             M          1972.0        33.0
# 3 2005-02-20     17:15          NaN             M          1986.0        19.0
# 4 2005-03-14     10:00          NaN             F          1984.0        21.0
#
#   driver_race     violation_raw violation  search_conducted search_type  \
# 0       White          Speeding  Speeding             False         NaN
# 1       White          Speeding  Speeding             False         NaN
# 2       White          Speeding  Speeding             False         NaN
# 3       White  Call for Service     Other             False         NaN
# 4       White          Speeding  Speeding             False         NaN
#
# ...
